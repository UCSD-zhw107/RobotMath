# %%
import sympy as sp
import numpy as np
import math

# %% [markdown]
# ## **Question 1.a Forward Kinematic**

# %%
theta0, theta1, theta2 = sp.symbols('theta0 theta1 theta2')

# %%
l0, l1, l2 = 10,10,10

# %%
x = l0 * sp.sin(theta0) + l1 * sp.sin(theta0 + theta1) + l2 * sp.sin(theta0 + theta1 + theta2)
y = 5 + l0 * sp.cos(theta0) + l1 * sp.cos(theta0 + theta1) + l2 * sp.cos(theta0 + theta1 + theta2)

# %%
dx_dtheta0 = sp.diff(x, theta0)
dx_dtheta1 = sp.diff(x, theta1)
dx_dtheta2 = sp.diff(x, theta2)

# %%
dy_dtheta0 = sp.diff(y, theta0)
dy_dtheta1 = sp.diff(y, theta1)
dy_dtheta2 = sp.diff(y, theta2)

# %%
print(f"dx/dtheta0: {dx_dtheta0}")
print(f"dx/dtheta1: {dx_dtheta1}")
print(f"dx/dtheta2: {dx_dtheta2}")
# Out:
# dx/dtheta0: 10*cos(theta0) + 10*cos(theta0 + theta1) + 10*cos(theta0 + theta1 + theta2)
# dx/dtheta1: 10*cos(theta0 + theta1) + 10*cos(theta0 + theta1 + theta2)
# dx/dtheta2: 10*cos(theta0 + theta1 + theta2)

# %%
print(f"dy/dtheta0: {dy_dtheta0}")
print(f"dy/dtheta1: {dy_dtheta1}")
print(f"dy/dtheta2: {dy_dtheta2}")
# Out:
# dy/dtheta0: -10*sin(theta0) - 10*sin(theta0 + theta1) - 10*sin(theta0 + theta1 + theta2)
# dy/dtheta1: -10*sin(theta0 + theta1) - 10*sin(theta0 + theta1 + theta2)
# dy/dtheta2: -10*sin(theta0 + theta1 + theta2)

# %% [markdown]
# ## **Question 1.b Inverse Kinematics**

# %%
import sympy as sp
import numpy as np

theta0, theta1, theta2 = sp.symbols('theta0 theta1 theta2')

l0, l1, l2 = 10, 10, 10

x = l0 * sp.sin(theta0) + l1 * sp.sin(theta0 + theta1) + l2 * sp.sin(theta0 + theta1 + theta2)
y = 5 + l0 * sp.cos(theta0) + l1 * sp.cos(theta0 + theta1) + l2 * sp.cos(theta0 + theta1 + theta2)

dx_dtheta0 = sp.diff(x, theta0)
dx_dtheta1 = sp.diff(x, theta1)
dx_dtheta2 = sp.diff(x, theta2)
dy_dtheta0 = sp.diff(y, theta0)
dy_dtheta1 = sp.diff(y, theta1)
dy_dtheta2 = sp.diff(y, theta2)

dx_dtheta0_func = sp.lambdify((theta0, theta1, theta2), dx_dtheta0)
dx_dtheta1_func = sp.lambdify((theta0, theta1, theta2), dx_dtheta1)
dx_dtheta2_func = sp.lambdify((theta0, theta1, theta2), dx_dtheta2)
dy_dtheta0_func = sp.lambdify((theta0, theta1, theta2), dy_dtheta0)
dy_dtheta1_func = sp.lambdify((theta0, theta1, theta2), dy_dtheta1)
dy_dtheta2_func = sp.lambdify((theta0, theta1, theta2), dy_dtheta2)

# %%
# Initial angle
theta0_val = 0
theta1_val = 0
theta2_val = 0

# Compute Jacobian
jacobian = np.array([
    [dx_dtheta0_func(theta0_val, theta1_val, theta2_val),
     dx_dtheta1_func(theta0_val, theta1_val, theta2_val),
     dx_dtheta2_func(theta0_val, theta1_val, theta2_val)],
    [dy_dtheta0_func(theta0_val, theta1_val, theta2_val),
     dy_dtheta1_func(theta0_val, theta1_val, theta2_val),
     dy_dtheta2_func(theta0_val, theta1_val, theta2_val)]
])

print("Jacobian:")
print(jacobian)
# Out:
# Jacobian:
# [[30. 20. 10.]
#  [-0. -0. -0.]]

# %%
import numpy as np
import math

# initial angle
theta0_val = 0
theta1_val = 0
theta2_val = 0

l0, l1, l2 = 10, 10, 10

# desired pose
target = np.array([10, 10])

# interation
max_iterations = 500  
error_threshold = 0  
step_size = 0.1  

# Constraint
angle_limit =  math.pi / 2

def calculate_jacobian(theta0_val, theta1_val, theta2_val):
    jacobian = np.array([
        [dx_dtheta0_func(theta0_val, theta1_val, theta2_val),
         dx_dtheta1_func(theta0_val, theta1_val, theta2_val),
         dx_dtheta2_func(theta0_val, theta1_val, theta2_val)],
        [dy_dtheta0_func(theta0_val, theta1_val, theta2_val),
         dy_dtheta1_func(theta0_val, theta1_val, theta2_val),
         dy_dtheta2_func(theta0_val, theta1_val, theta2_val)]
    ])
    return jacobian

def calculate_position(theta0_val, theta1_val, theta2_val):
    x_new = l0 * math.sin(theta0_val) + l1 * math.sin(theta0_val + theta1_val) + l2 * math.sin(theta0_val + theta1_val + theta2_val)
    y_new = 5 + l0 * math.cos(theta0_val) + l1 * math.cos(theta0_val + theta1_val) + l2 * math.cos(theta0_val + theta1_val + theta2_val)
    return np.array([x_new, y_new])

for iteration in range(max_iterations):
    # Current position
    current_position = calculate_position(theta0_val, theta1_val, theta2_val)

    # Current dx
    position_error = target - current_position

    # Break at error_threshold
    if np.linalg.norm(position_error) < error_threshold:
        print(f"Stoped at: {iteration}")
        break

    # Update Jacobian
    jacobian = calculate_jacobian(theta0_val, theta1_val, theta2_val)
    U, Sigma, Vt = np.linalg.svd(jacobian)
    Sigma_inv = np.zeros((Vt.shape[0], U.shape[1]))
    for i in range(len(Sigma)):
        if Sigma[i] > 1e-10: 
            Sigma_inv[i, i] = 1.0 / Sigma[i]
    jacobian_inv = np.dot(Vt.T, np.dot(Sigma_inv, U.T))

    # dtheta
    delta_theta = np.dot(jacobian_inv, position_error)

    # Update theta
    theta0_val = np.clip(theta0_val + step_size * delta_theta[0], -angle_limit, angle_limit)
    theta1_val = np.clip(theta1_val + step_size * delta_theta[1], -angle_limit, angle_limit)
    theta2_val = np.clip(theta2_val + step_size * delta_theta[2], -angle_limit, angle_limit)

    print(f"iteration {iteration + 1}:")
    print(f"  q0（radius） = {theta0_val:.4f}， q0（degree） = {math.degrees(theta0_val):.3f}°")
    print(f"  q1（radius） = {theta1_val:.4f}， q1（degree） = {math.degrees(theta1_val):.3f}°")
    print(f"  q2（radius） = {theta2_val:.4f}， q2（degree） = {math.degrees(theta2_val):.3f}°")

final_position = calculate_position(theta0_val, theta1_val, theta2_val)
print(f"Final Position: x={final_position[0]}, y={final_position[1]}")
# Out:
# iteration 1:
#   q0（radius） = 0.0214， q0（degree） = 1.228°
#   q1（radius） = 0.0143， q1（degree） = 0.819°
#   q2（radius） = 0.0071， q2（degree） = 0.409°
# iteration 2:
#   q0（radius） = -1.5708， q0（degree） = -90.000°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.5708， q2（degree） = 90.000°
# iteration 3:
#   q0（radius） = -1.5208， q0（degree） = -87.135°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.5708， q2（degree） = 90.000°
# iteration 4:
#   q0（radius） = -1.4709， q0（degree） = -84.276°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.5684， q2（degree） = 89.862°
# iteration 5:
#   q0（radius） = -1.4215， q0（degree） = -81.446°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.5640， q2（degree） = 89.611°
# iteration 6:
#   q0（radius） = -1.3729， q0（degree） = -78.663°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.5581， q2（degree） = 89.270°
# iteration 7:
#   q0（radius） = -1.3255， q0（degree） = -75.943°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.5509， q2（degree） = 88.861°
# iteration 8:
#   q0（radius） = -1.2793， q0（degree） = -73.299°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.5429， q2（degree） = 88.402°
# iteration 9:
#   q0（radius） = -1.2346， q0（degree） = -70.740°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.5343， q2（degree） = 87.907°
# iteration 10:
#   q0（radius） = -1.1916， q0（degree） = -68.274°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.5253， q2（degree） = 87.392°
# iteration 11:
#   q0（radius） = -1.1503， q0（degree） = -65.907°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.5161， q2（degree） = 86.866°
# iteration 12:
#   q0（radius） = -1.1108， q0（degree） = -63.641°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.5069， q2（degree） = 86.339°
# iteration 13:
#   q0（radius） = -1.0730， q0（degree） = -61.480°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4978， q2（degree） = 85.819°
# iteration 14:
#   q0（radius） = -1.0371， q0（degree） = -59.423°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4890， q2（degree） = 85.313°
# iteration 15:
#   q0（radius） = -1.0030， q0（degree） = -57.470°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4805， q2（degree） = 84.824°
# iteration 16:
#   q0（radius） = -0.9707， q0（degree） = -55.620°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4723， q2（degree） = 84.357°
# iteration 17:
#   q0（radius） = -0.9402， q0（degree） = -53.870°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4646， q2（degree） = 83.914°
# iteration 18:
#   q0（radius） = -0.9114， q0（degree） = -52.218°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4573， q2（degree） = 83.498°
# iteration 19:
#   q0（radius） = -0.8842， q0（degree） = -50.661°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4505， q2（degree） = 83.109°
# iteration 20:
#   q0（radius） = -0.8586， q0（degree） = -49.195°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4442， q2（degree） = 82.749°
# iteration 21:
#   q0（radius） = -0.8346， q0（degree） = -47.817°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4384， q2（degree） = 82.416°
# iteration 22:
#   q0（radius） = -0.8120， q0（degree） = -46.522°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4331， q2（degree） = 82.112°
# iteration 23:
#   q0（radius） = -0.7907， q0（degree） = -45.306°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4283， q2（degree） = 81.835°
# iteration 24:
#   q0（radius） = -0.7708， q0（degree） = -44.166°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4239， q2（degree） = 81.584°
# iteration 25:
#   q0（radius） = -0.7522， q0（degree） = -43.098°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4200， q2（degree） = 81.359°
# iteration 26:
#   q0（radius） = -0.7347， q0（degree） = -42.097°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4165， q2（degree） = 81.159°
# iteration 27:
#   q0（radius） = -0.7184， q0（degree） = -41.159°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4134， q2（degree） = 80.981°
# iteration 28:
#   q0（radius） = -0.7031， q0（degree） = -40.282°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4107， q2（degree） = 80.826°
# iteration 29:
#   q0（radius） = -0.6887， q0（degree） = -39.461°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4083， q2（degree） = 80.691°
# iteration 30:
#   q0（radius） = -0.6753， q0（degree） = -38.693°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4063， q2（degree） = 80.576°
# iteration 31:
#   q0（radius） = -0.6628， q0（degree） = -37.974°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4046， q2（degree） = 80.478°
# iteration 32:
#   q0（radius） = -0.6510， q0（degree） = -37.301°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4032， q2（degree） = 80.397°
# iteration 33:
#   q0（radius） = -0.6400， q0（degree） = -36.672°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4021， q2（degree） = 80.332°
# iteration 34:
#   q0（radius） = -0.6298， q0（degree） = -36.083°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4012， q2（degree） = 80.280°
# iteration 35:
#   q0（radius） = -0.6202， q0（degree） = -35.532°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4005， q2（degree） = 80.242°
# iteration 36:
#   q0（radius） = -0.6112， q0（degree） = -35.017°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4000， q2（degree） = 80.215°
# iteration 37:
#   q0（radius） = -0.6027， q0（degree） = -34.534°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.3997， q2（degree） = 80.199°
# iteration 38:
#   q0（radius） = -0.5948， q0（degree） = -34.082°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.3996， q2（degree） = 80.193°
# iteration 39:
#   q0（radius） = -0.5875， q0（degree） = -33.658°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.3997， q2（degree） = 80.195°
# iteration 40:
#   q0（radius） = -0.5805， q0（degree） = -33.262°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.3999， q2（degree） = 80.206°
# iteration 41:
#   q0（radius） = -0.5740， q0（degree） = -32.889°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4002， q2（degree） = 80.223°
# iteration 42:
#   q0（radius） = -0.5679， q0（degree） = -32.540°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4006， q2（degree） = 80.247°
# iteration 43:
#   q0（radius） = -0.5622， q0（degree） = -32.213°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4011， q2（degree） = 80.277°
# iteration 44:
#   q0（radius） = -0.5569， q0（degree） = -31.905°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4017， q2（degree） = 80.311°
# iteration 45:
#   q0（radius） = -0.5518， q0（degree） = -31.617°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4024， q2（degree） = 80.350°
# iteration 46:
#   q0（radius） = -0.5471， q0（degree） = -31.345°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4031， q2（degree） = 80.392°
# iteration 47:
#   q0（radius） = -0.5426， q0（degree） = -31.090°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4039， q2（degree） = 80.438°
# iteration 48:
#   q0（radius） = -0.5384， q0（degree） = -30.850°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4047， q2（degree） = 80.486°
# iteration 49:
#   q0（radius） = -0.5345， q0（degree） = -30.624°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4056， q2（degree） = 80.537°
# iteration 50:
#   q0（radius） = -0.5308， q0（degree） = -30.411°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4066， q2（degree） = 80.590°
# iteration 51:
#   q0（radius） = -0.5273， q0（degree） = -30.210°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4075， q2（degree） = 80.644°
# iteration 52:
#   q0（radius） = -0.5240， q0（degree） = -30.021°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4085， q2（degree） = 80.700°
# iteration 53:
#   q0（radius） = -0.5208， q0（degree） = -29.842°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4095， q2（degree） = 80.756°
# iteration 54:
#   q0（radius） = -0.5179， q0（degree） = -29.673°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4105， q2（degree） = 80.813°
# iteration 55:
#   q0（radius） = -0.5151， q0（degree） = -29.514°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4115， q2（degree） = 80.871°
# iteration 56:
#   q0（radius） = -0.5125， q0（degree） = -29.363°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4125， q2（degree） = 80.929°
# iteration 57:
#   q0（radius） = -0.5100， q0（degree） = -29.220°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4135， q2（degree） = 80.987°
# iteration 58:
#   q0（radius） = -0.5076， q0（degree） = -29.085°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4145， q2（degree） = 81.045°
# iteration 59:
#   q0（radius） = -0.5054， q0（degree） = -28.958°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4155， q2（degree） = 81.102°
# iteration 60:
#   q0（radius） = -0.5033， q0（degree） = -28.836°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4165， q2（degree） = 81.159°
# iteration 61:
#   q0（radius） = -0.5013， q0（degree） = -28.722°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4175， q2（degree） = 81.216°
# iteration 62:
#   q0（radius） = -0.4994， q0（degree） = -28.612°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4185， q2（degree） = 81.272°
# iteration 63:
#   q0（radius） = -0.4976， q0（degree） = -28.509°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4194， q2（degree） = 81.327°
# iteration 64:
#   q0（radius） = -0.4959， q0（degree） = -28.411°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4204， q2（degree） = 81.381°
# iteration 65:
#   q0（radius） = -0.4942， q0（degree） = -28.317°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4213， q2（degree） = 81.435°
# iteration 66:
#   q0（radius） = -0.4927， q0（degree） = -28.228°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4222， q2（degree） = 81.488°
# iteration 67:
#   q0（radius） = -0.4912， q0（degree） = -28.144°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4231， q2（degree） = 81.539°
# iteration 68:
#   q0（radius） = -0.4898， q0（degree） = -28.063°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4240， q2（degree） = 81.590°
# iteration 69:
#   q0（radius） = -0.4885， q0（degree） = -27.987°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4249， q2（degree） = 81.640°
# iteration 70:
#   q0（radius） = -0.4872， q0（degree） = -27.914°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4257， q2（degree） = 81.688°
# iteration 71:
#   q0（radius） = -0.4860， q0（degree） = -27.844°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4266， q2（degree） = 81.736°
# iteration 72:
#   q0（radius） = -0.4848， q0（degree） = -27.778°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4274， q2（degree） = 81.782°
# iteration 73:
#   q0（radius） = -0.4837， q0（degree） = -27.714°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4282， q2（degree） = 81.827°
# iteration 74:
#   q0（radius） = -0.4826， q0（degree） = -27.654°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4289， q2（degree） = 81.871°
# iteration 75:
#   q0（radius） = -0.4816， q0（degree） = -27.596°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4297， q2（degree） = 81.914°
# iteration 76:
#   q0（radius） = -0.4807， q0（degree） = -27.541°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4304， q2（degree） = 81.956°
# iteration 77:
#   q0（radius） = -0.4798， q0（degree） = -27.488°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4311， q2（degree） = 81.997°
# iteration 78:
#   q0（radius） = -0.4789， q0（degree） = -27.437°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4318， q2（degree） = 82.037°
# iteration 79:
#   q0（radius） = -0.4780， q0（degree） = -27.389°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4325， q2（degree） = 82.075°
# iteration 80:
#   q0（radius） = -0.4772， q0（degree） = -27.343°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4331， q2（degree） = 82.113°
# iteration 81:
#   q0（radius） = -0.4765， q0（degree） = -27.299°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4338， q2（degree） = 82.149°
# iteration 82:
#   q0（radius） = -0.4757， q0（degree） = -27.257°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4344， q2（degree） = 82.185°
# iteration 83:
#   q0（radius） = -0.4750， q0（degree） = -27.216°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4350， q2（degree） = 82.219°
# iteration 84:
#   q0（radius） = -0.4743， q0（degree） = -27.177°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4356， q2（degree） = 82.252°
# iteration 85:
#   q0（radius） = -0.4737， q0（degree） = -27.140°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4361， q2（degree） = 82.285°
# iteration 86:
#   q0（radius） = -0.4731， q0（degree） = -27.104°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4367， q2（degree） = 82.316°
# iteration 87:
#   q0（radius） = -0.4725， q0（degree） = -27.070°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4372， q2（degree） = 82.347°
# iteration 88:
#   q0（radius） = -0.4719， q0（degree） = -27.037°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4377， q2（degree） = 82.376°
# iteration 89:
#   q0（radius） = -0.4713， q0（degree） = -27.006°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4382， q2（degree） = 82.405°
# iteration 90:
#   q0（radius） = -0.4708， q0（degree） = -26.976°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4387， q2（degree） = 82.432°
# iteration 91:
#   q0（radius） = -0.4703， q0（degree） = -26.947°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4392， q2（degree） = 82.459°
# iteration 92:
#   q0（radius） = -0.4698， q0（degree） = -26.919°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4396， q2（degree） = 82.485°
# iteration 93:
#   q0（radius） = -0.4694， q0（degree） = -26.892°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4401， q2（degree） = 82.510°
# iteration 94:
#   q0（radius） = -0.4689， q0（degree） = -26.867°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4405， q2（degree） = 82.535°
# iteration 95:
#   q0（radius） = -0.4685， q0（degree） = -26.842°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4409， q2（degree） = 82.558°
# iteration 96:
#   q0（radius） = -0.4681， q0（degree） = -26.818°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4413， q2（degree） = 82.581°
# iteration 97:
#   q0（radius） = -0.4677， q0（degree） = -26.796°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4417， q2（degree） = 82.603°
# iteration 98:
#   q0（radius） = -0.4673， q0（degree） = -26.774°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4421， q2（degree） = 82.624°
# iteration 99:
#   q0（radius） = -0.4669， q0（degree） = -26.753°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4424， q2（degree） = 82.645°
# iteration 100:
#   q0（radius） = -0.4666， q0（degree） = -26.733°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4428， q2（degree） = 82.665°
# iteration 101:
#   q0（radius） = -0.4662， q0（degree） = -26.713°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4431， q2（degree） = 82.684°
# iteration 102:
#   q0（radius） = -0.4659， q0（degree） = -26.695°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4434， q2（degree） = 82.703°
# iteration 103:
#   q0（radius） = -0.4656， q0（degree） = -26.677°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4437， q2（degree） = 82.721°
# iteration 104:
#   q0（radius） = -0.4653， q0（degree） = -26.659°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4441， q2（degree） = 82.738°
# iteration 105:
#   q0（radius） = -0.4650， q0（degree） = -26.643°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4443， q2（degree） = 82.755°
# iteration 106:
#   q0（radius） = -0.4647， q0（degree） = -26.627°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4446， q2（degree） = 82.771°
# iteration 107:
#   q0（radius） = -0.4645， q0（degree） = -26.611°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4449， q2（degree） = 82.787°
# iteration 108:
#   q0（radius） = -0.4642， q0（degree） = -26.597°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4452， q2（degree） = 82.802°
# iteration 109:
#   q0（radius） = -0.4640， q0（degree） = -26.582°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4454， q2（degree） = 82.817°
# iteration 110:
#   q0（radius） = -0.4637， q0（degree） = -26.569°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4457， q2（degree） = 82.831°
# iteration 111:
#   q0（radius） = -0.4635， q0（degree） = -26.556°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4459， q2（degree） = 82.845°
# iteration 112:
#   q0（radius） = -0.4633， q0（degree） = -26.543°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4461， q2（degree） = 82.858°
# iteration 113:
#   q0（radius） = -0.4630， q0（degree） = -26.531°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4464， q2（degree） = 82.871°
# iteration 114:
#   q0（radius） = -0.4628， q0（degree） = -26.519°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4466， q2（degree） = 82.883°
# iteration 115:
#   q0（radius） = -0.4626， q0（degree） = -26.508°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4468， q2（degree） = 82.895°
# iteration 116:
#   q0（radius） = -0.4625， q0（degree） = -26.497°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4470， q2（degree） = 82.906°
# iteration 117:
#   q0（radius） = -0.4623， q0（degree） = -26.486°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4472， q2（degree） = 82.917°
# iteration 118:
#   q0（radius） = -0.4621， q0（degree） = -26.476°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4474， q2（degree） = 82.928°
# iteration 119:
#   q0（radius） = -0.4619， q0（degree） = -26.466°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4475， q2（degree） = 82.938°
# iteration 120:
#   q0（radius） = -0.4618， q0（degree） = -26.457°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4477， q2（degree） = 82.948°
# iteration 121:
#   q0（radius） = -0.4616， q0（degree） = -26.448°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4479， q2（degree） = 82.958°
# iteration 122:
#   q0（radius） = -0.4615， q0（degree） = -26.439°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4481， q2（degree） = 82.967°
# iteration 123:
#   q0（radius） = -0.4613， q0（degree） = -26.431°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4482， q2（degree） = 82.976°
# iteration 124:
#   q0（radius） = -0.4612， q0（degree） = -26.423°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4484， q2（degree） = 82.985°
# iteration 125:
#   q0（radius） = -0.4610， q0（degree） = -26.415°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4485， q2（degree） = 82.993°
# iteration 126:
#   q0（radius） = -0.4609， q0（degree） = -26.407°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4486， q2（degree） = 83.001°
# iteration 127:
#   q0（radius） = -0.4608， q0（degree） = -26.400°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4488， q2（degree） = 83.009°
# iteration 128:
#   q0（radius） = -0.4606， q0（degree） = -26.393°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4489， q2（degree） = 83.017°
# iteration 129:
#   q0（radius） = -0.4605， q0（degree） = -26.387°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4490， q2（degree） = 83.024°
# iteration 130:
#   q0（radius） = -0.4604， q0（degree） = -26.380°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4492， q2（degree） = 83.031°
# iteration 131:
#   q0（radius） = -0.4603， q0（degree） = -26.374°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4493， q2（degree） = 83.038°
# iteration 132:
#   q0（radius） = -0.4602， q0（degree） = -26.368°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4494， q2（degree） = 83.044°
# iteration 133:
#   q0（radius） = -0.4601， q0（degree） = -26.362°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4495， q2（degree） = 83.051°
# iteration 134:
#   q0（radius） = -0.4600， q0（degree） = -26.357°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4496， q2（degree） = 83.057°
# iteration 135:
#   q0（radius） = -0.4599， q0（degree） = -26.351°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4497， q2（degree） = 83.063°
# iteration 136:
#   q0（radius） = -0.4598， q0（degree） = -26.346°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4498， q2（degree） = 83.068°
# iteration 137:
#   q0（radius） = -0.4597， q0（degree） = -26.341°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4499， q2（degree） = 83.074°
# iteration 138:
#   q0（radius） = -0.4597， q0（degree） = -26.336°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4500， q2（degree） = 83.079°
# iteration 139:
#   q0（radius） = -0.4596， q0（degree） = -26.332°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4501， q2（degree） = 83.084°
# iteration 140:
#   q0（radius） = -0.4595， q0（degree） = -26.327°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4502， q2（degree） = 83.089°
# iteration 141:
#   q0（radius） = -0.4594， q0（degree） = -26.323°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4503， q2（degree） = 83.094°
# iteration 142:
#   q0（radius） = -0.4593， q0（degree） = -26.319°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4503， q2（degree） = 83.098°
# iteration 143:
#   q0（radius） = -0.4593， q0（degree） = -26.315°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4504， q2（degree） = 83.103°
# iteration 144:
#   q0（radius） = -0.4592， q0（degree） = -26.311°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4505， q2（degree） = 83.107°
# iteration 145:
#   q0（radius） = -0.4591， q0（degree） = -26.307°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4506， q2（degree） = 83.111°
# iteration 146:
#   q0（radius） = -0.4591， q0（degree） = -26.303°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4506， q2（degree） = 83.115°
# iteration 147:
#   q0（radius） = -0.4590， q0（degree） = -26.300°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4507， q2（degree） = 83.119°
# iteration 148:
#   q0（radius） = -0.4590， q0（degree） = -26.297°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4508， q2（degree） = 83.122°
# iteration 149:
#   q0（radius） = -0.4589， q0（degree） = -26.293°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4508， q2（degree） = 83.126°
# iteration 150:
#   q0（radius） = -0.4589， q0（degree） = -26.290°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4509， q2（degree） = 83.129°
# iteration 151:
#   q0（radius） = -0.4588， q0（degree） = -26.287°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4509， q2（degree） = 83.133°
# iteration 152:
#   q0（radius） = -0.4588， q0（degree） = -26.285°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4510， q2（degree） = 83.136°
# iteration 153:
#   q0（radius） = -0.4587， q0（degree） = -26.282°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4510， q2（degree） = 83.139°
# iteration 154:
#   q0（radius） = -0.4587， q0（degree） = -26.279°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4511， q2（degree） = 83.142°
# iteration 155:
#   q0（radius） = -0.4586， q0（degree） = -26.277°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4512， q2（degree） = 83.145°
# iteration 156:
#   q0（radius） = -0.4586， q0（degree） = -26.274°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4512， q2（degree） = 83.148°
# iteration 157:
#   q0（radius） = -0.4585， q0（degree） = -26.272°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4512， q2（degree） = 83.150°
# iteration 158:
#   q0（radius） = -0.4585， q0（degree） = -26.269°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4513， q2（degree） = 83.153°
# iteration 159:
#   q0（radius） = -0.4584， q0（degree） = -26.267°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4513， q2（degree） = 83.155°
# iteration 160:
#   q0（radius） = -0.4584， q0（degree） = -26.265°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4514， q2（degree） = 83.158°
# iteration 161:
#   q0（radius） = -0.4584， q0（degree） = -26.263°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4514， q2（degree） = 83.160°
# iteration 162:
#   q0（radius） = -0.4583， q0（degree） = -26.261°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4515， q2（degree） = 83.162°
# iteration 163:
#   q0（radius） = -0.4583， q0（degree） = -26.259°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4515， q2（degree） = 83.164°
# iteration 164:
#   q0（radius） = -0.4583， q0（degree） = -26.257°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4515， q2（degree） = 83.166°
# iteration 165:
#   q0（radius） = -0.4582， q0（degree） = -26.255°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4516， q2（degree） = 83.168°
# iteration 166:
#   q0（radius） = -0.4582， q0（degree） = -26.254°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4516， q2（degree） = 83.170°
# iteration 167:
#   q0（radius） = -0.4582， q0（degree） = -26.252°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4516， q2（degree） = 83.172°
# iteration 168:
#   q0（radius） = -0.4582， q0（degree） = -26.250°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4517， q2（degree） = 83.174°
# iteration 169:
#   q0（radius） = -0.4581， q0（degree） = -26.249°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4517， q2（degree） = 83.176°
# iteration 170:
#   q0（radius） = -0.4581， q0（degree） = -26.247°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4517， q2（degree） = 83.177°
# iteration 171:
#   q0（radius） = -0.4581， q0（degree） = -26.246°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4517， q2（degree） = 83.179°
# iteration 172:
#   q0（radius） = -0.4581， q0（degree） = -26.244°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4518， q2（degree） = 83.181°
# iteration 173:
#   q0（radius） = -0.4580， q0（degree） = -26.243°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4518， q2（degree） = 83.182°
# iteration 174:
#   q0（radius） = -0.4580， q0（degree） = -26.242°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4518， q2（degree） = 83.183°
# iteration 175:
#   q0（radius） = -0.4580， q0（degree） = -26.241°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4518， q2（degree） = 83.185°
# iteration 176:
#   q0（radius） = -0.4580， q0（degree） = -26.239°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4519， q2（degree） = 83.186°
# iteration 177:
#   q0（radius） = -0.4579， q0（degree） = -26.238°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4519， q2（degree） = 83.187°
# iteration 178:
#   q0（radius） = -0.4579， q0（degree） = -26.237°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4519， q2（degree） = 83.189°
# iteration 179:
#   q0（radius） = -0.4579， q0（degree） = -26.236°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4519， q2（degree） = 83.190°
# iteration 180:
#   q0（radius） = -0.4579， q0（degree） = -26.235°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4520， q2（degree） = 83.191°
# iteration 181:
#   q0（radius） = -0.4579， q0（degree） = -26.234°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4520， q2（degree） = 83.192°
# iteration 182:
#   q0（radius） = -0.4579， q0（degree） = -26.233°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4520， q2（degree） = 83.193°
# iteration 183:
#   q0（radius） = -0.4578， q0（degree） = -26.232°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4520， q2（degree） = 83.194°
# iteration 184:
#   q0（radius） = -0.4578， q0（degree） = -26.231°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4520， q2（degree） = 83.195°
# iteration 185:
#   q0（radius） = -0.4578， q0（degree） = -26.230°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4520， q2（degree） = 83.196°
# iteration 186:
#   q0（radius） = -0.4578， q0（degree） = -26.230°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4521， q2（degree） = 83.197°
# iteration 187:
#   q0（radius） = -0.4578， q0（degree） = -26.229°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4521， q2（degree） = 83.198°
# iteration 188:
#   q0（radius） = -0.4578， q0（degree） = -26.228°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4521， q2（degree） = 83.199°
# iteration 189:
#   q0（radius） = -0.4578， q0（degree） = -26.227°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4521， q2（degree） = 83.200°
# iteration 190:
#   q0（radius） = -0.4577， q0（degree） = -26.226°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4521， q2（degree） = 83.201°
# iteration 191:
#   q0（radius） = -0.4577， q0（degree） = -26.226°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4521， q2（degree） = 83.201°
# iteration 192:
#   q0（radius） = -0.4577， q0（degree） = -26.225°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4522， q2（degree） = 83.202°
# iteration 193:
#   q0（radius） = -0.4577， q0（degree） = -26.224°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4522， q2（degree） = 83.203°
# iteration 194:
#   q0（radius） = -0.4577， q0（degree） = -26.224°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4522， q2（degree） = 83.204°
# iteration 195:
#   q0（radius） = -0.4577， q0（degree） = -26.223°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4522， q2（degree） = 83.204°
# iteration 196:
#   q0（radius） = -0.4577， q0（degree） = -26.223°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4522， q2（degree） = 83.205°
# iteration 197:
#   q0（radius） = -0.4577， q0（degree） = -26.222°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4522， q2（degree） = 83.206°
# iteration 198:
#   q0（radius） = -0.4577， q0（degree） = -26.222°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4522， q2（degree） = 83.206°
# iteration 199:
#   q0（radius） = -0.4576， q0（degree） = -26.221°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4522， q2（degree） = 83.207°
# iteration 200:
#   q0（radius） = -0.4576， q0（degree） = -26.221°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4522， q2（degree） = 83.207°
# iteration 201:
#   q0（radius） = -0.4576， q0（degree） = -26.220°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4523， q2（degree） = 83.208°
# iteration 202:
#   q0（radius） = -0.4576， q0（degree） = -26.220°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4523， q2（degree） = 83.208°
# iteration 203:
#   q0（radius） = -0.4576， q0（degree） = -26.219°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4523， q2（degree） = 83.209°
# iteration 204:
#   q0（radius） = -0.4576， q0（degree） = -26.219°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4523， q2（degree） = 83.209°
# iteration 205:
#   q0（radius） = -0.4576， q0（degree） = -26.218°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4523， q2（degree） = 83.210°
# iteration 206:
#   q0（radius） = -0.4576， q0（degree） = -26.218°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4523， q2（degree） = 83.210°
# iteration 207:
#   q0（radius） = -0.4576， q0（degree） = -26.217°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4523， q2（degree） = 83.211°
# iteration 208:
#   q0（radius） = -0.4576， q0（degree） = -26.217°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4523， q2（degree） = 83.211°
# iteration 209:
#   q0（radius） = -0.4576， q0（degree） = -26.217°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4523， q2（degree） = 83.212°
# iteration 210:
#   q0（radius） = -0.4576， q0（degree） = -26.216°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4523， q2（degree） = 83.212°
# iteration 211:
#   q0（radius） = -0.4576， q0（degree） = -26.216°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4523， q2（degree） = 83.212°
# iteration 212:
#   q0（radius） = -0.4576， q0（degree） = -26.216°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4523， q2（degree） = 83.213°
# iteration 213:
#   q0（radius） = -0.4575， q0（degree） = -26.215°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4523， q2（degree） = 83.213°
# iteration 214:
#   q0（radius） = -0.4575， q0（degree） = -26.215°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4523， q2（degree） = 83.213°
# iteration 215:
#   q0（radius） = -0.4575， q0（degree） = -26.215°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4524， q2（degree） = 83.214°
# iteration 216:
#   q0（radius） = -0.4575， q0（degree） = -26.215°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4524， q2（degree） = 83.214°
# iteration 217:
#   q0（radius） = -0.4575， q0（degree） = -26.214°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4524， q2（degree） = 83.214°
# iteration 218:
#   q0（radius） = -0.4575， q0（degree） = -26.214°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4524， q2（degree） = 83.215°
# iteration 219:
#   q0（radius） = -0.4575， q0（degree） = -26.214°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4524， q2（degree） = 83.215°
# iteration 220:
#   q0（radius） = -0.4575， q0（degree） = -26.214°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4524， q2（degree） = 83.215°
# iteration 221:
#   q0（radius） = -0.4575， q0（degree） = -26.213°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4524， q2（degree） = 83.215°
# iteration 222:
#   q0（radius） = -0.4575， q0（degree） = -26.213°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4524， q2（degree） = 83.216°
# iteration 223:
#   q0（radius） = -0.4575， q0（degree） = -26.213°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4524， q2（degree） = 83.216°
# iteration 224:
#   q0（radius） = -0.4575， q0（degree） = -26.213°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4524， q2（degree） = 83.216°
# iteration 225:
#   q0（radius） = -0.4575， q0（degree） = -26.212°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4524， q2（degree） = 83.216°
# iteration 226:
#   q0（radius） = -0.4575， q0（degree） = -26.212°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4524， q2（degree） = 83.217°
# iteration 227:
#   q0（radius） = -0.4575， q0（degree） = -26.212°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4524， q2（degree） = 83.217°
# iteration 228:
#   q0（radius） = -0.4575， q0（degree） = -26.212°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4524， q2（degree） = 83.217°
# iteration 229:
#   q0（radius） = -0.4575， q0（degree） = -26.212°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4524， q2（degree） = 83.217°
# iteration 230:
#   q0（radius） = -0.4575， q0（degree） = -26.212°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4524， q2（degree） = 83.217°
# iteration 231:
#   q0（radius） = -0.4575， q0（degree） = -26.211°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4524， q2（degree） = 83.218°
# iteration 232:
#   q0（radius） = -0.4575， q0（degree） = -26.211°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4524， q2（degree） = 83.218°
# iteration 233:
#   q0（radius） = -0.4575， q0（degree） = -26.211°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4524， q2（degree） = 83.218°
# iteration 234:
#   q0（radius） = -0.4575， q0（degree） = -26.211°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4524， q2（degree） = 83.218°
# iteration 235:
#   q0（radius） = -0.4575， q0（degree） = -26.211°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4524， q2（degree） = 83.218°
# iteration 236:
#   q0（radius） = -0.4575， q0（degree） = -26.211°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4524， q2（degree） = 83.218°
# iteration 237:
#   q0（radius） = -0.4575， q0（degree） = -26.211°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4524， q2（degree） = 83.219°
# iteration 238:
#   q0（radius） = -0.4575， q0（degree） = -26.210°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4524， q2（degree） = 83.219°
# iteration 239:
#   q0（radius） = -0.4575， q0（degree） = -26.210°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4524， q2（degree） = 83.219°
# iteration 240:
#   q0（radius） = -0.4575， q0（degree） = -26.210°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4524， q2（degree） = 83.219°
# iteration 241:
#   q0（radius） = -0.4575， q0（degree） = -26.210°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4524， q2（degree） = 83.219°
# iteration 242:
#   q0（radius） = -0.4574， q0（degree） = -26.210°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.219°
# iteration 243:
#   q0（radius） = -0.4574， q0（degree） = -26.210°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.219°
# iteration 244:
#   q0（radius） = -0.4574， q0（degree） = -26.210°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.220°
# iteration 245:
#   q0（radius） = -0.4574， q0（degree） = -26.210°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.220°
# iteration 246:
#   q0（radius） = -0.4574， q0（degree） = -26.210°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.220°
# iteration 247:
#   q0（radius） = -0.4574， q0（degree） = -26.209°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.220°
# iteration 248:
#   q0（radius） = -0.4574， q0（degree） = -26.209°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.220°
# iteration 249:
#   q0（radius） = -0.4574， q0（degree） = -26.209°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.220°
# iteration 250:
#   q0（radius） = -0.4574， q0（degree） = -26.209°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.220°
# iteration 251:
#   q0（radius） = -0.4574， q0（degree） = -26.209°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.220°
# iteration 252:
#   q0（radius） = -0.4574， q0（degree） = -26.209°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.220°
# iteration 253:
#   q0（radius） = -0.4574， q0（degree） = -26.209°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.220°
# iteration 254:
#   q0（radius） = -0.4574， q0（degree） = -26.209°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.220°
# iteration 255:
#   q0（radius） = -0.4574， q0（degree） = -26.209°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.221°
# iteration 256:
#   q0（radius） = -0.4574， q0（degree） = -26.209°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.221°
# iteration 257:
#   q0（radius） = -0.4574， q0（degree） = -26.209°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.221°
# iteration 258:
#   q0（radius） = -0.4574， q0（degree） = -26.209°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.221°
# iteration 259:
#   q0（radius） = -0.4574， q0（degree） = -26.209°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.221°
# iteration 260:
#   q0（radius） = -0.4574， q0（degree） = -26.208°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.221°
# iteration 261:
#   q0（radius） = -0.4574， q0（degree） = -26.208°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.221°
# iteration 262:
#   q0（radius） = -0.4574， q0（degree） = -26.208°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.221°
# iteration 263:
#   q0（radius） = -0.4574， q0（degree） = -26.208°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.221°
# iteration 264:
#   q0（radius） = -0.4574， q0（degree） = -26.208°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.221°
# iteration 265:
#   q0（radius） = -0.4574， q0（degree） = -26.208°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.221°
# iteration 266:
#   q0（radius） = -0.4574， q0（degree） = -26.208°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.221°
# iteration 267:
#   q0（radius） = -0.4574， q0（degree） = -26.208°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.221°
# iteration 268:
#   q0（radius） = -0.4574， q0（degree） = -26.208°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.221°
# iteration 269:
#   q0（radius） = -0.4574， q0（degree） = -26.208°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.221°
# iteration 270:
#   q0（radius） = -0.4574， q0（degree） = -26.208°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.221°
# iteration 271:
#   q0（radius） = -0.4574， q0（degree） = -26.208°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.221°
# iteration 272:
#   q0（radius） = -0.4574， q0（degree） = -26.208°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.221°
# iteration 273:
#   q0（radius） = -0.4574， q0（degree） = -26.208°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.222°
# iteration 274:
#   q0（radius） = -0.4574， q0（degree） = -26.208°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.222°
# iteration 275:
#   q0（radius） = -0.4574， q0（degree） = -26.208°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.222°
# iteration 276:
#   q0（radius） = -0.4574， q0（degree） = -26.208°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.222°
# iteration 277:
#   q0（radius） = -0.4574， q0（degree） = -26.208°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.222°
# iteration 278:
#   q0（radius） = -0.4574， q0（degree） = -26.208°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.222°
# iteration 279:
#   q0（radius） = -0.4574， q0（degree） = -26.208°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.222°
# iteration 280:
#   q0（radius） = -0.4574， q0（degree） = -26.208°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.222°
# iteration 281:
#   q0（radius） = -0.4574， q0（degree） = -26.208°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.222°
# iteration 282:
#   q0（radius） = -0.4574， q0（degree） = -26.208°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.222°
# iteration 283:
#   q0（radius） = -0.4574， q0（degree） = -26.208°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.222°
# iteration 284:
#   q0（radius） = -0.4574， q0（degree） = -26.208°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.222°
# iteration 285:
#   q0（radius） = -0.4574， q0（degree） = -26.208°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.222°
# iteration 286:
#   q0（radius） = -0.4574， q0（degree） = -26.208°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.222°
# iteration 287:
#   q0（radius） = -0.4574， q0（degree） = -26.208°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.222°
# iteration 288:
#   q0（radius） = -0.4574， q0（degree） = -26.208°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.222°
# iteration 289:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.222°
# iteration 290:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.222°
# iteration 291:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.222°
# iteration 292:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.222°
# iteration 293:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.222°
# iteration 294:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.222°
# iteration 295:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.222°
# iteration 296:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.222°
# iteration 297:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.222°
# iteration 298:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.222°
# iteration 299:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.222°
# iteration 300:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.222°
# iteration 301:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.222°
# iteration 302:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.222°
# iteration 303:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.222°
# iteration 304:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.222°
# iteration 305:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.222°
# iteration 306:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.222°
# iteration 307:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.222°
# iteration 308:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.222°
# iteration 309:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.222°
# iteration 310:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.222°
# iteration 311:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.222°
# iteration 312:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.222°
# iteration 313:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.222°
# iteration 314:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.222°
# iteration 315:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.222°
# iteration 316:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.222°
# iteration 317:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.222°
# iteration 318:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.222°
# iteration 319:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.222°
# iteration 320:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.222°
# iteration 321:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.222°
# iteration 322:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.222°
# iteration 323:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
# ...
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 395:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 396:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 397:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 398:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 399:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 400:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 401:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 402:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 403:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 404:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 405:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 406:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 407:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 408:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 409:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 410:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 411:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 412:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 413:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 414:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 415:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 416:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 417:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 418:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 419:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 420:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 421:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 422:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 423:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 424:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 425:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 426:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 427:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 428:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 429:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 430:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 431:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 432:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 433:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 434:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 435:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 436:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 437:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 438:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 439:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 440:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 441:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 442:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 443:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 444:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 445:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 446:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 447:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 448:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 449:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 450:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 451:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 452:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 453:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 454:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 455:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 456:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 457:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 458:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 459:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 460:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 461:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 462:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 463:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 464:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 465:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 466:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 467:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 468:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 469:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 470:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 471:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 472:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 473:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 474:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 475:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 476:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 477:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 478:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 479:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 480:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 481:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 482:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 483:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 484:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 485:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 486:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 487:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 488:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 489:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 490:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 491:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 492:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 493:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 494:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 495:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 496:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 497:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 498:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 499:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# iteration 500:
#   q0（radius） = -0.4574， q0（degree） = -26.207°
#   q1（radius） = 1.5708， q1（degree） = 90.000°
#   q2（radius） = 1.4525， q2（degree） = 83.223°
# Final Position: x=10.000000020139478, y=10.000000073094194

# %%
#Final Jacobian
jacobian = np.array([
        [dx_dtheta0_func(theta0_val, theta1_val, theta2_val),
         dx_dtheta1_func(theta0_val, theta1_val, theta2_val),
         dx_dtheta2_func(theta0_val, theta1_val, theta2_val)],
        [dy_dtheta0_func(theta0_val, theta1_val, theta2_val),
         dy_dtheta1_func(theta0_val, theta1_val, theta2_val),
         dy_dtheta2_func(theta0_val, theta1_val, theta2_val)]
    ])

# %%
from scipy.linalg import null_space
null_space_of_jacobian = null_space(jacobian)

# %%
print(null_space_of_jacobian)
# Out:
# [[ 0.53304618]
#  [-0.59639478]
#  [ 0.60014584]]

# %% [markdown]
# ## **Question 2.a Homograph Matrix**

# %%
import numpy as np

count = 0
img_count = 1
img_coord = {}
entry = []

with open('./imgpoints.txt', 'r') as file:
    for line in file:
        count += 1
        u, v = map(float, line.strip().split(' ', 1))  # Convert u, v to float and remove '\n'
        entry.append(np.array([u, v]))  # Append to current entry
        if count % 48 == 0:
            img_coord[img_count] = np.array(entry)  # Store entry as array
            img_count += 1
            entry = []  # Reset entry for the next 48 lines
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[41], line 8
#       5 img_coord = {}
#       6 entry = []
# ----> 8 with open('./imgpoints.txt', 'r') as file:
#       9     for line in file:
#      10         count += 1
#
# File D:\Anaconda\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: './imgpoints.txt'

# %%
import numpy as np
import matplotlib.pyplot as plt

# Assuming img_coord is already populated

# Define colors for each group to differentiate them in the plot
colors = ['red', 'green', 'blue', 'orange', 'purple', 'cyan']

# Plot the UV coordinates for each image
for img_num, uv_coords in img_coord.items():
    plt.figure(figsize=(8, 8))  # Create a new figure for each image

    # Plot and connect UV points in batches of 8
    for group_num in range(6):  # 6 groups (48 points total, 8 per group)
        group_start = group_num * 8
        group_end = group_start + 8
        u_vals = uv_coords[group_start:group_end, 0]  # u values for this group
        v_vals = uv_coords[group_start:group_end, 1]  # v values for this group
        
        # Plot the UV points
        plt.scatter(u_vals, v_vals, c=colors[group_num], label=f'Group {group_num + 1}')
        
        # Connect the points in this group with lines
        plt.plot(u_vals, v_vals, c=colors[group_num], linestyle='-', marker='o')

        # Annotate the group number at the midpoint of each group of 8 points
        midpoint_idx = len(u_vals) // 2
        plt.text(u_vals[midpoint_idx], v_vals[midpoint_idx], f'Group {group_num + 1}',
                 fontsize=10, color=colors[group_num], fontweight='bold')

    # Labeling the plot
    plt.title(f'UV Coordinates for Image {img_num} with Group Connections')
    plt.xlabel('u (x-axis)')
    plt.ylabel('v (y-axis)')
    plt.gca().invert_yaxis()  # Invert the y-axis to match the image coordinates
    plt.grid(True)
    plt.legend()

    # Show the plot for each image
    plt.show()

# %%
import numpy as np
#Generate Checkerboard Coordinates

square_size = 25  # size of each checkerboard square in mm
x_corners = 8  # number of corners along x-axis
y_corners = 6  # number of corners along y-axis

# The starting point is at the top-left corner (25, 150)
start_x = 25
start_y = 150


checkerboard_coords = []


for j in range(y_corners):
    current_y = start_y - j * square_size  
    for i in range(x_corners):
        current_x = start_x + i * square_size 
        checkerboard_coords.append([current_x, current_y])


checkerboard_coords = np.array(checkerboard_coords)

# %%
#Normalize Data
for img_ind in img_coord.keys():
    uv_coord = img_coord[img_ind]
    for (X, Y), (u, v) in zip(checkerboard_coords, uv_coord):
        x_matrix = np.array([X,Y, 1]).reshape(-1,1)
        u_matrix = np.array([u, v, 1]).reshape(-1,1)
# Out:
# [[ 25]
#  [150]
#  [  1]]
# [[140.90712 ]
#  [178.364182]
#  [  1.      ]]

# %%
#Stack M for each image
img_M = {}

#Create Linear Equation
def create_matrix_for_point(X, Y, u, v):
    # Create the matrix for a single pair of (X, Y) and (u, v)
    row1 = [-X, -Y, -1, 0, 0, 0, u * X, u * Y, u]
    row2 = [0, 0, 0, -X, -Y, -1, v * X, v * Y, v]
    
    return np.array([row1, row2])

for img_ind in img_coord.keys():
    M_i = []
    uv_coord = img_coord[img_ind]
    for (X, Y), (u, v) in zip(checkerboard_coords, uv_coord):
        M_i.append(create_matrix_for_point(X, Y, u, v))
    M_i = np.vstack(M_i)
    img_M[img_ind] = M_i

# %%
#Solve for h
img_h = {}
for img_ind in img_M:
    M_i = img_M[img_ind]
    U, Sigma, Vt = np.linalg.svd(M_i)
    Sigma_matrix = np.diag(Sigma)
    sigma = np.diagonal(Sigma_matrix)
    k = np.argmin(sigma)
    h = Vt[k]
    H = h.reshape(3, 3)
    img_h[img_ind] = H

# %%
#Calculate L2 Norm
img_dis = {}
for img_id in img_h.keys():
    print(f'Euclidean Distance of img: {img_id} is:', end = ' ')
    
    uv_coord = img_coord[img_id]  # Use img_id instead of img_ind
    distance = 0
    for (X, Y), (u, v) in zip(checkerboard_coords, uv_coord):
        # Convert (X, Y) to homogeneous coordinates by appending 1
        XY_homogeneous = np.array([X, Y, 1])
        
        # Apply the homography matrix
        transformed_XY = np.dot(img_h[img_id], XY_homogeneous)
        
        # Normalize by the third coordinate (to convert back to Cartesian coordinates)
        transformed_XY = transformed_XY / transformed_XY[2]
        
        # Compute the Euclidean distance between (u, v) and the transformed (X, Y)
        distance += np.linalg.norm(np.array([u, v]) - transformed_XY[:2])
    img_dis[img_id] = distance
    print(img_dis[img_id])
# Out:
# Euclidean Distance of img: 1 is: 20.410786045031163
# Euclidean Distance of img: 2 is: 19.044338135491596
# Euclidean Distance of img: 3 is: 17.946066354721363
# Euclidean Distance of img: 4 is: 20.01044225330703
# Euclidean Distance of img: 5 is: 16.035028048220166
# Euclidean Distance of img: 6 is: 17.33739011773513
# Euclidean Distance of img: 7 is: 16.908029798524623
# Euclidean Distance of img: 8 is: 16.548779963663094
# Euclidean Distance of img: 9 is: 18.64958109453924

# %% [markdown]
# ## **Question 2.b Intrinsic Camera Matrix**

# %%
#Create v(H)
def create_v_H(H, p, q):
    v1 = np.dot(H[0][p], H[0][q])
    v2 = np.dot(H[0][p], H[1][q]) + np.dot(H[1][p], H[0][q])
    v3 = np.dot(H[1][p], H[1][q])
    v4 = np.dot(H[2][p], H[0][q]) + np.dot(H[0][p], H[2][q])
    v5 = np.dot(H[2][p], H[1][q]) + np.dot(H[1][p], H[2][q])
    v6 = np.dot(H[2][p], H[2][q])
    v = np.array([v1,v2,v3,v4,v5,v6])
    return v

#Create Linear equation for each H
def create_Li(H):
    l1 = create_v_H(H, 0, 1)
    l2 = create_v_H(H, 0, 0) - create_v_H(H, 1, 1)
    return np.vstack([l1, l2])


#Create linear equation for all H
def create_L(img_h):
    img_count = len(img_h.keys())
    L = []
    for img_id in img_h.keys():
        L.append(create_Li(img_h[img_id]))
    L_s = np.vstack(L)
    U, Sigma, Vt = np.linalg.svd(L_s)
    Sigma_matrix = np.diag(Sigma)
    sigma = np.diagonal(Sigma_matrix)
    k = np.argmin(sigma)
    b = Vt[k]
    return b

# %%
#Create A
b = create_L(img_h)
w = b[0]*b[2]*b[5] - (b[1]**2)*b[5] - b[0]*(b[4]**2) + 2*b[1]*b[3]*b[4] - b[2] * (b[3]**2)
d = b[0] * b[2] - (b[1] ** 2)
alpha = math.sqrt(w / (d * b[0]))
beta = math.sqrt(w/(d**2) * b[0])
gamma = math.sqrt(w / ((d**2) * b[0])) * b[1]
u_c = (b[1] * b[4] - b[2] * b[3]) / d
v_c = (b[1] * b[3] - b[0] * b[4]) / d
A = np.array([[alpha, gamma, u_c],[0, beta, v_c],[0,0,1]])
print(A)
# Out:
# [[621.52696958  21.71845314 347.78367576]
#  [  0.         606.99841401 192.05560201]
#  [  0.           0.           1.        ]]

# %% [markdown]
# ## **Question 2.c Extrinsic Matrix**

# %%
#Calculate (R|t) for each image
A_inv = np.linalg.inv(A)
img_R = {}
img_t = {}
for img_ind in img_h.keys():
    h0 = img_h[img_ind][:,0].reshape(-1, 1)
    h1 = img_h[img_ind][:,1].reshape(-1, 1)
    h2 = img_h[img_ind][:,2].reshape(-1, 1)
    lambd = 1 / (np.linalg.norm(np.dot(A_inv, h0)))
    r0 = np.dot(lambd, np.dot(A_inv, h0))
    r1 = np.dot(lambd, np.dot(A_inv, h1))
    t = np.dot(lambd, np.dot(A_inv, h2))
    r2 = np.cross(r0.flatten(), r1.flatten()).reshape(-1, 1)
    img_R[img_ind] = np.hstack((r0,r1,r2))
    img_t[img_ind] = t
print(img_R[1])
print(img_t[1])
# Out:
# [[ 0.99257449 -0.1104312  -0.03447198]
#  [-0.09318829 -0.54692093 -0.83122391]
#  [ 0.0781782   0.82874445 -0.55315066]]
# [[-181.90664711]
#  [  72.56884657]
#  [ 397.27978243]]
